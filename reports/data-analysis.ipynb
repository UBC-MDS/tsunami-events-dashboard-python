# %%
import pandas as pd

# %%
RAW_FILE_PATH = "../data/raw/tsunami-events.tsv"
PROCESSED_FILE_PATH = "../data/processed/tsunami-events.csv"

# %% [markdown]
# ### Data Cleaning

# %%
tsunami_df = pd.read_csv(RAW_FILE_PATH, sep="\t")
tsunami_df.head()
# Out:
#   Search Parameters    Year  Mo  Dy  Hr  Mn  Sec  Tsunami Event Validity  \
# 0                []     NaN NaN NaN NaN NaN  NaN                     NaN
# 1               NaN -2000.0 NaN NaN NaN NaN  NaN                     1.0
# 2               NaN -1610.0 NaN NaN NaN NaN  NaN                     4.0
# 3               NaN -1365.0 NaN NaN NaN NaN  NaN                     1.0
# 4               NaN -1300.0 NaN NaN NaN NaN  NaN                     2.0
#
#    Tsunami Cause Code  Earthquake Magnitude  ...  Total Missing  \
# 0                 NaN                   NaN  ...            NaN
# 1                 1.0                   NaN  ...            NaN
# 2                 6.0                   NaN  ...            NaN
# 3                 1.0                   NaN  ...            NaN
# 4                 0.0                   6.0  ...            NaN
#
#    Total Missing Description  Total Injuries Total Injuries Description  \
# 0                        NaN             NaN                        NaN
# 1                        NaN             NaN                        NaN
# 2                        NaN             NaN                        NaN
# 3                        NaN             NaN                        NaN
# 4                        NaN             NaN                        NaN
#
#   Total Damage ($Mil)  Total Damage Description  Total Houses Destroyed  \
# 0                 NaN                       NaN                     NaN
# 1                 NaN                       4.0                     NaN
# 2                 NaN                       3.0                     NaN
# 3                 NaN                       3.0                     NaN
# 4                 NaN                       NaN                     NaN
#
#    Total Houses Destroyed Description  Total Houses Damaged  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
#
#    Total Houses Damaged Description
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 46 columns]

# %%
tsunami_df.columns
# Out:
# Index(['Search Parameters', 'Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec',
#        'Tsunami Event Validity', 'Tsunami Cause Code', 'Earthquake Magnitude',
#        'Vol', 'More Info', 'Deposits', 'Country', 'Location Name', 'Latitude',
#        'Longitude', 'Maximum Water Height (m)', 'Number of Runups',
#        'Tsunami Magnitude (Abe)', 'Tsunami Magnitude (Iida)',
#        'Tsunami Intensity', 'Deaths', 'Death Description', 'Missing',
#        'Missing Description', 'Injuries', 'Injuries Description',
#        'Damage ($Mil)', 'Damage Description', 'Houses Destroyed',
#        'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
#        'Total Houses Damaged Description'],
#       dtype='object')

# %%
features_selected = [
    "Year",
    "Mo",
    "Tsunami Event Validity",
    "Earthquake Magnitude",
    "Country",
    "Location Name",
    "Latitude",
    "Longitude",
    "Tsunami Intensity",
    "Total Deaths",
    "Total Damage ($Mil)",
    "Total Houses Destroyed",
    "Total Injuries"
]

filtered_df = (
    tsunami_df
    .loc[tsunami_df["Year"] >= 1500, features_selected]
    .reset_index(drop=True)
)
filtered_df
# Out:
#         Year   Mo  Tsunami Event Validity  Earthquake Magnitude      Country  \
# 0     1500.0  7.0                    -1.0                   NaN        JAPAN
# 1     1500.0  NaN                     2.0                   NaN          USA
# 2     1504.0  4.0                     1.0                   NaN     PORTUGAL
# 3     1508.0  5.0                     2.0                   7.1       GREECE
# 4     1509.0  6.0                     2.0                   NaN        CHINA
# ...      ...  ...                     ...                   ...          ...
# 2594  2022.0  1.0                     4.0                   NaN        TONGA
# 2595  2022.0  1.0                     4.0                   NaN        TONGA
# 2596  2022.0  1.0                     4.0                   NaN        TONGA
# 2597  2022.0  1.0                     4.0                   NaN        TONGA
# 2598  2022.0  1.0                     4.0                   6.5  NEW ZEALAND
#
#          Location Name  Latitude  Longitude  Tsunami Intensity  Total Deaths  \
# 0              TOKAIDO       NaN        NaN                NaN           NaN
# 1               HAWAII       NaN        NaN                NaN           NaN
# 2               LISBON       NaN        NaN                NaN           NaN
# 3      ISLAND OF CRETE    35.000     25.500                3.0           NaN
# 4      SOUTH CHINA SEA    31.500    121.500                0.0           NaN
# ...                ...       ...        ...                ...           ...
# 2594     TONGA ISLANDS   -20.536   -175.382                NaN           NaN
# 2595     TONGA ISLANDS   -20.536   -175.382                NaN           NaN
# 2596     TONGA ISLANDS   -20.536   -175.382                NaN           6.0
# 2597     TONGA ISLANDS   -20.536   -175.382                NaN           NaN
# 2598  KERMADEC ISLANDS   -29.531   -176.749                NaN           NaN
#
#       Total Damage ($Mil)  Total Houses Destroyed  Total Injuries
# 0                     NaN                     NaN             NaN
# 1                     NaN                     NaN             NaN
# 2                     NaN                     NaN             NaN
# 3                     NaN                     NaN             NaN
# 4                     NaN                     NaN             NaN
# ...                   ...                     ...             ...
# 2594                  NaN                     NaN             NaN
# 2595                  NaN                     NaN             NaN
# 2596                 96.9                     NaN            20.0
# 2597                  NaN                     NaN             NaN
# 2598                  NaN                     NaN             NaN
#
# [2599 rows x 13 columns]

# %%
filtered_df.columns = ["_".join(c.lower().split(" ")) for c in filtered_df.columns]
filtered_df = filtered_df.rename({
    "total_damage_($mil)": "total_damage_millions",
    "mo": "month"
}, axis=1)

# %%
filtered_df["month"] = pd.to_datetime(filtered_df['month'], format='%m').dt.month_name()
filtered_df["year"] = filtered_df["year"].astype(int)

# %%
filtered_df.head()
# Out:
#    year  month  tsunami_event_validity  earthquake_magnitude   country  \
# 0  1500   July                    -1.0                   NaN     JAPAN
# 1  1500    NaN                     2.0                   NaN       USA
# 2  1504  April                     1.0                   NaN  PORTUGAL
# 3  1508    May                     2.0                   7.1    GREECE
# 4  1509   June                     2.0                   NaN     CHINA
#
#      location_name  latitude  longitude  tsunami_intensity  total_deaths  \
# 0          TOKAIDO       NaN        NaN                NaN           NaN
# 1           HAWAII       NaN        NaN                NaN           NaN
# 2           LISBON       NaN        NaN                NaN           NaN
# 3  ISLAND OF CRETE      35.0       25.5                3.0           NaN
# 4  SOUTH CHINA SEA      31.5      121.5                0.0           NaN
#
#    total_damage_millions  total_houses_destroyed  total_injuries
# 0                    NaN                     NaN             NaN
# 1                    NaN                     NaN             NaN
# 2                    NaN                     NaN             NaN
# 3                    NaN                     NaN             NaN
# 4                    NaN                     NaN             NaN

# %%
filtered_df.to_csv(PROCESSED_FILE_PATH)
