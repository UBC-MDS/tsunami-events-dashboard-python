# %%
import pandas as pd

# %%
RAW_FILE_PATH = "../data/raw/tsunami-events.tsv"
PROCESSED_FILE_PATH = "../data/processed/tsunami-events.csv"
COUNTRY_CODES_FILE_PATH = "../data/processed/country_codes.csv"

# %% [markdown]
# ### Data Cleaning

# %%
tsunami_df = pd.read_csv(RAW_FILE_PATH, sep="\t")
tsunami_df.head()
# Out:
#   Search Parameters    Year  Mo  Dy  Hr  Mn  Sec  Tsunami Event Validity  \
# 0                []     NaN NaN NaN NaN NaN  NaN                     NaN
# 1               NaN -2000.0 NaN NaN NaN NaN  NaN                     1.0
# 2               NaN -1610.0 NaN NaN NaN NaN  NaN                     4.0
# 3               NaN -1365.0 NaN NaN NaN NaN  NaN                     1.0
# 4               NaN -1300.0 NaN NaN NaN NaN  NaN                     2.0
#
#    Tsunami Cause Code  Earthquake Magnitude  ...  Total Missing  \
# 0                 NaN                   NaN  ...            NaN
# 1                 1.0                   NaN  ...            NaN
# 2                 6.0                   NaN  ...            NaN
# 3                 1.0                   NaN  ...            NaN
# 4                 0.0                   6.0  ...            NaN
#
#    Total Missing Description  Total Injuries Total Injuries Description  \
# 0                        NaN             NaN                        NaN
# 1                        NaN             NaN                        NaN
# 2                        NaN             NaN                        NaN
# 3                        NaN             NaN                        NaN
# 4                        NaN             NaN                        NaN
#
#   Total Damage ($Mil)  Total Damage Description  Total Houses Destroyed  \
# 0                 NaN                       NaN                     NaN
# 1                 NaN                       4.0                     NaN
# 2                 NaN                       3.0                     NaN
# 3                 NaN                       3.0                     NaN
# 4                 NaN                       NaN                     NaN
#
#    Total Houses Destroyed Description  Total Houses Damaged  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
#
#    Total Houses Damaged Description
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 46 columns]

# %%
tsunami_df.columns
# Out:
# Index(['Search Parameters', 'Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec',
#        'Tsunami Event Validity', 'Tsunami Cause Code', 'Earthquake Magnitude',
#        'Vol', 'More Info', 'Deposits', 'Country', 'Location Name', 'Latitude',
#        'Longitude', 'Maximum Water Height (m)', 'Number of Runups',
#        'Tsunami Magnitude (Abe)', 'Tsunami Magnitude (Iida)',
#        'Tsunami Intensity', 'Deaths', 'Death Description', 'Missing',
#        'Missing Description', 'Injuries', 'Injuries Description',
#        'Damage ($Mil)', 'Damage Description', 'Houses Destroyed',
#        'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
#        'Total Houses Damaged Description'],
#       dtype='object')

# %%
features_selected = [
    "Year",
    "Mo",
    "Tsunami Event Validity",
    "Tsunami Cause Code",
    "Earthquake Magnitude",
    "Country",
    "Location Name",
    "Latitude",
    "Longitude",
    "Tsunami Intensity",
    "Total Deaths",
    "Total Damage ($Mil)",
    "Total Houses Destroyed",
    "Total Injuries"
]

filtered_df = (
    tsunami_df
    .loc[tsunami_df["Year"] >= 1800, features_selected]
    .reset_index(drop=True)
)

# %%
filtered_df.columns = ["_".join(c.lower().split(" ")) for c in filtered_df.columns]
filtered_df = filtered_df.rename({
    "total_damage_($mil)": "total_damage_millions",
    "mo": "month"
}, axis=1)

# %%
filtered_df["month"] = pd.to_datetime(filtered_df['month'], format='%m').dt.month_name()
filtered_df["year"] = filtered_df["year"].astype(int)

# %%
filtered_df.head()
# Out:
#    year    month  tsunami_event_validity  tsunami_cause_code  \
# 0  1800     June                     2.0                 1.0
# 1  1802  January                     2.0                 1.0
# 2  1802    March                     2.0                 1.0
# 3  1802   August                     1.0                 0.0
# 4  1802   August                     3.0                 1.0
#
#    earthquake_magnitude              country  \
# 0                   NaN             PORTUGAL
# 1                   NaN              CROATIA
# 2                   NaN  ANTIGUA AND BARBUDA
# 3                   NaN                   UK
# 4                   NaN            VENEZUELA
#
#                       location_name  latitude  longitude  tsunami_intensity  \
# 0                            AZORES       NaN        NaN                NaN
# 1                             BAKAR      45.3       14.4                3.0
# 2  ANTIGUA ISLAND & ST. CHRISTOPHER      17.2      -62.4                NaN
# 3                        SW ENGLAND       NaN        NaN                NaN
# 4                            CUMANA      10.3      -64.5                NaN
#
#    total_deaths  total_damage_millions  total_houses_destroyed  total_injuries
# 0           NaN                    NaN                     NaN             NaN
# 1           NaN                    NaN                     NaN             NaN
# 2           NaN                    NaN                     NaN             NaN
# 3           NaN                    NaN                     NaN             NaN
# 4           NaN                    NaN                     NaN             NaN

# %%
filtered_df = filtered_df[(filtered_df["tsunami_event_validity"] == 4) &
                          (filtered_df["tsunami_cause_code"] == 1) &
                          (filtered_df["earthquake_magnitude"] > 0)]

replace_country = {
    "RUSSIA": "Russian Federation",
    "USA": "United States of America",
    "IRAN": "Iran, Islamic Republic of",
    "MYANMAR (BURMA)": "Myanmar",
    "SOUTH KOREA": "Korea, Republic of",
    "TAIWAN": "Taiwan, Province of China",
    "VENEZUELA": "Venezuela (Bolivarian Republic of)",
    "GUADELOUPE (FRENCH TERRITORY)": "Guadeloupe",
    "MARTINIQUE (FRENCH TERRITORY)": "Martinique",
    "SAMOA": "Samoa",
    "TONGA": "Tonga",
    "USA TERRITORY": "United States of America",
    "UK TERRITORY": "United Kingdom of Great Britain and Northern Ireland",
}

filtered_df["country"] = (
    filtered_df["country"]
    .replace(replace_country)
    .str.title()
    .str.replace("Of", "of")
    .str.replace("And", "and")
)

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 668 entries, 7 to 2166
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    668 non-null    int64
#  1   month                   668 non-null    object
#  2   tsunami_event_validity  668 non-null    float64
#  3   tsunami_cause_code      668 non-null    float64
#  4   earthquake_magnitude    668 non-null    float64
#  5   country                 668 non-null    object
#  6   location_name           668 non-null    object
#  7   latitude                668 non-null    float64
#  8   longitude               668 non-null    float64
#  9   tsunami_intensity       302 non-null    float64
#  10  total_deaths            233 non-null    float64
#  11  total_damage_millions   85 non-null     float64
#  12  total_houses_destroyed  121 non-null    float64
#  13  total_injuries          178 non-null    float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 78.3+ KB

# %%
country_codes = pd.read_csv(COUNTRY_CODES_FILE_PATH)
not_countries = set(filtered_df["country"]) - set(country_codes["name"])
filtered_df = filtered_df[~filtered_df["country"].isin(not_countries)]

filtered_df.to_csv(PROCESSED_FILE_PATH, index=False)

# %%
import altair as alt
from vega_datasets import data


world_map = alt.topo_feature(data.world_110m.url, 'countries')

events = filtered_df.groupby("country").size().reset_index(name='count')
events = events.merge(country_codes, how="right", left_on="country", right_on="name")
events["count"] = events["count"].fillna(0)

map = (
    alt.Chart(world_map)
    .mark_geoshape(stroke="grey", strokeWidth=0.3)
    .transform_lookup(
        lookup="id",
        from_=alt.LookupData(events, "country-code", ["name", "count"])
    )
    .encode(color=alt.condition("datum.count>0.0",
                                alt.Color("count:Q",
                                          scale=alt.Scale(scheme='blues',
                                                          domainMin=1,
                                                          domainMid=11),
                                          legend=alt.Legend(orient='bottom-left'),
                                          title="Total Tsunami Hits"),
                                alt.ColorValue("white")),
            tooltip=[alt.Tooltip("name:N", title="Country"),
                     alt.Tooltip("count:Q", title="Total Tsunami Hits")])
    .project("naturalEarth1")
    .properties(width=800, height=400)
)

filtered_df["color"] = "Tsunami Origin"

tsunami_spots = (
    alt.Chart(filtered_df)
    .mark_circle(size=5, color="red")
    .encode(
        latitude="latitude",
        longitude="longitude",
        color=alt.Color("color:N",
                        scale=alt.Scale(scheme="reds", domainMax=1),
                        legend=alt.Legend(title="", orient='top-left')),
        tooltip=[alt.Tooltip("earthquake_magnitude",
                 title="Earthquake Magnitude")]
    )
)

map + tsunami_spots
# Out:
# alt.LayerChart(...)
